# %%
# Step 1: Install Required Packages
# !pip install transformers torch streamlit pyngrok

# Step 2: Configure ngrok Authtoken
# !ngrok config add-authtoken 2ofbTsKytOnVm9dSF3C9vZFdtdq_4t21j3U6XJQuZgt4VjKV9  # Replace with your actual authtoken

# Step 3: Import Libraries and Initialize ngrok
from pyngrok import ngrok
import streamlit as st
from transformers import pipeline

# Step 4: Initialize Text Generation Model
generator = pipeline("text-generation", model="gpt2")

# Step 5: Define the Chatbot UI and Functionality
def chatbot():
    st.title("🌐 Generative AI Customer Support Chatbot")
    st.write("Hello! I'm here to assist you with creative, AI-powered responses. Ask me anything!")

    # Input from the user
    user_input = st.text_input("You:", "Type your question here...")

    # If there's user input, generate a response
    if user_input:
        with st.spinner("Thinking..."):
            response = generator(
                user_input,
                max_length=60,       # Controls response length
                num_return_sequences=1,
                temperature=0.75     # Controls creativity (higher = more creative)
            )
            bot_response = response[0]["generated_text"]
            st.write("🤖 Bot:", bot_response)

# Step 6: Save Streamlit App Code to app.py
with open("app.py", "w") as f:
    f.write("""
import streamlit as st
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

def chatbot():
    st.title("🌐 Generative AI Customer Support Chatbot")
    st.write("Hello! I'm here to assist you with creative, AI-powered responses. Ask me anything!")

    user_input = st.text_input("You:", "Type your question here...")

    if user_input:
        with st.spinner("Thinking..."):
            response = generator(
                user_input,
                max_length=60,
                num_return_sequences=1,
                temperature=0.75
            )
            bot_response = response[0]["generated_text"]
            st.write("🤖 Bot:", bot_response)

if __name__ == '__main__':
    chatbot()
""")

# Step 7: Start ngrok to Get Public URL for Streamlit
ngrok_tunnel = ngrok.connect(8501)
print("Access your chatbot here:", ngrok_tunnel.public_url)

# Step 8: Run the Streamlit App
# !streamlit run app.py &>/dev/null &
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 661.7 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 25.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 27.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 4.5 MB/s eta 0:00:00
# ...
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# ...
